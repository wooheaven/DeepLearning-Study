# %%
from IPython.display import Image, display

# %%
with open('02_implement_signal_of_each_layer/02_implement_signal_of_each_layer.png','rb') as f:
    display(Image(f.read()))

# %%
import numpy as np

# %%
X = np.array([1.0,0.5])
W1 = np.array([[0.1,0.3,0.5],[0.2,0.4,0.6]])
B1 = np.array([0.1,0.2,0.3])

# %%
A1 = np.dot(X, W1) + B1

# %%
A1
# Out:
# array([0.3, 0.7, 1.1])
