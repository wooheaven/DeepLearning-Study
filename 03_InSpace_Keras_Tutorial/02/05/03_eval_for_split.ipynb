# %%
from IPython.display import Image, display

# %% [markdown]
# # 1 Split
# ## 1-1 레고블럭 분할하기 : 가운데 2x2 를 녹색으로 나머지는 노랑으로 분할하자
# ## 1-2 어떤 모델이 잘 분할했는가 ?

# %%
print('A to E Model Result : ex A Model is not perfect result.' )
with open('A_to_E_Model.png', 'rb') as f:
    display(Image(f.read()))
# Out:
# A to E Model Result : ex A Model is not perfect result.

# %% [markdown]
# # 2 Eval of Split
# ## 2-1 Pixcel Accuracy (blocks) = (matched green + matched yellow) / all

# %%
print('Pixel Accuracy : ex A Model 79% pixcel acc = (4 + 15) / 24')
with open('A_to_E_Pixcel_Accuracy.png', 'rb') as f:
    display(Image(f.read()))
# Out:
# Pixel Accuracy : ex A Model 79% pixcel acc = (4 + 15) / 24

# %%
# Model E is not acceptable for Pixel Accuracy.
# divide [ matched green and yellow ] to [ matched green and matched yellow ]

# %% [markdown]
# ## 2-2 Mean Accuracy = (matched g / all g + matched y / all y) / 2

# %%
print('Mean Accuracy : ex A Model 88 % pixcel acc = (4/4 + 15/20) / 2')
with open('A_to_E_Mean_Accuracy.png', 'rb') as f:
    display(Image(f.read()))
# Out:
# Mean Accuracy : ex A Model 88 % pixcel acc = (4/4 + 15/20) / 2

# %%
# Model C is not acceptable for Mean Accuracy.
# add penalty for wrong (not only plus for correct)

# %% [markdown]
# ## 2-3 Mean IU = Mean Intersection over Union = (matched g / union g + matched y / union y ) / 2

# %%
print('Union = Predicted Result ∪ Original')
print('IU = Intersection over Union')
with open('Union.png', 'rb') as f:
    display(Image(f.read()))
# Out:
# Union = Predicted Result ∪ Original
# IU = Intersection over Union

# %%
print('Mean IU : ex A Model 59.7 % = (4/9 + 15/20) / 2')
with open('A_to_E_Mean_IU.png', 'rb') as f:
    display(Image(f.read()))
# Out:
# Mean IU : ex A Model 59.7 % = (4/9 + 15/20) / 2

# %%
# Model B and C are not acceptable for Mean IU
# Add weight by frequency.

# %%
print('Frequency Weighted IU : ex A Model 69.9% = (4 * 4/9 + 20 * 15/20) / 24')
with open('A_to_E_Frequency_Weighted_IU.png', 'rb') as f:
    display(Image(f.read()))
# Out:
# Frequency Weighted IU : ex A Model 69.9% = (4 * 4/9 + 20 * 15/20) / 24

# %%
# User can define eval for some reason.
