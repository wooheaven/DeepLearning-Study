# %%
# 0. 사용할 패키지 불러오기
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense

# 랜덤시드 고정시키기
np.random.seed(5)
# Out:
# Using TensorFlow backend.

# %%
# 1. 데이터 준비하기
dataset = np.loadtxt("./warehouse/pima-indians-diabetes.data.txt", delimiter=",")

# %%
# 2. 데이터셋 생성하기
x_train = dataset[:700,0:8]
y_train = dataset[:700,8]
x_val = dataset[700:,0:8]
y_val = dataset[700:,8]

# %%
# 3. 모델 구성하기
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# 4. 모델 학습과정 설정하기
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# 5. 모델 학습시키기
tb_hist = keras.callbacks.TensorBoard(log_dir='./log', histogram_freq=0, write_graph=True, write_images=True)
hist = model.fit(x_train, y_train, epochs=1500, batch_size=64, validation_data=(x_val, y_val), callbacks=[tb_hist])
# Out:
# Train on 700 samples, validate on 68 samples
# Epoch 1/1500
# 700/700 [==============================] - 0s 70us/step - loss: 4.3523 - acc: 0.6543 - val_loss: 3.9656 - val_acc: 0.5735
# Epoch 2/1500
# 700/700 [==============================] - 0s 26us/step - loss: 3.6546 - acc: 0.6429 - val_loss: 3.2909 - val_acc: 0.6176
# Epoch 3/1500
# 700/700 [==============================] - 0s 42us/step - loss: 3.4536 - acc: 0.6129 - val_loss: 2.9535 - val_acc: 0.6324
# Epoch 4/1500
# 700/700 [==============================] - 0s 38us/step - loss: 3.0977 - acc: 0.6286 - val_loss: 2.5408 - val_acc: 0.6324
# Epoch 5/1500
# 700/700 [==============================] - 0s 50us/step - loss: 2.6379 - acc: 0.6614 - val_loss: 1.8708 - val_acc: 0.7353
# Epoch 6/1500
# 700/700 [==============================] - 0s 41us/step - loss: 2.1432 - acc: 0.6571 - val_loss: 1.4752 - val_acc: 0.6618
# Epoch 7/1500
# ...

# %%
# bash
# tensorboard --logdir=./log

# %%
# 6. 모델 평가하기
scores = model.evaluate(x_val, y_val)
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))
# Out:
# 68/68 [==============================] - 0s 96us/step
# acc: 76.47%

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

SVG(model_to_dot(model, show_shapes=True).create(prog='dot', format='svg'))
